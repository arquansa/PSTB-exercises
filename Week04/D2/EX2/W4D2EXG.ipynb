# %% [markdown]
# <a href="https://colab.research.google.com/github/arquansa/PSTB-exercises/blob/main/Week04/D2/EX2/W4D2EXG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises XP Gold
# Last Updated: December 5th, 2024
#
# 👩‍🏫 👩🏿‍🏫 What You’ll learn
# Eigenvectors and their role in understanding linear transformations of a matrix.
# Matrix normalization techniques and their importance in machine learning algorithms.
#
#
# 🛠️ What you will create
# Advanced exercises involving eigenvectors and matrix normalization, enhancing your understanding of these concepts and their applications in data analysis and machine learning.
#
#
# Exercise 1 : Advanced Matrix Operations
# Instructions
# Reminder: Eigenvectors are used to understand the linear transformations of a matrix. They show the directions in which a matrix, when applied, stretches the space.
#
# Matrix normalization is the process of adjusting the values in the matrix to a common scale, without distorting differences in the ranges of values. It’s used to bring all the variables to a uniform scale. This is particularly useful in machine learning algorithms that calculate distances between data.
#
# Create a 5x5 matrix with random numbers and perform the following operations:
# 1. Calculate the eigenvalues and eigenvectors.
# 2. Perform matrix normalization.
#
# Exercise 2 : Statistical Distribution Analysis
# Instructions
# Hint:
# - To generate a dataset following a normal distribution, you can use numpy’s np.random.normal() function. F
# - or plotting its histogram, matplotlib’s plt.hist() can be used.
#
# - Generate a dataset following a normal distribution and plot its histogram. Then,
# - calculate and interpret its skewness and kurtosis.
#
# Exercise 3 : Time Series Forecasting
# Instructions
#
#
# import numpy as np
#
# # Generating monthly sales data as a NumPy array
# monthly_sales_data = np.random.randint(100, 500, size=12)  # Random sales data for 12 months
#
# Using a simple NumPy array representing time series data (e.g., monthly sales data), demonstrate how to forecast future data points using linear regression.
#
# Exercise 4 : Pandas Data Aggregation
# Instructions
#
# import pandas as pd
#
# # Creating a sample Pandas DataFrame
# data = {
#     'Product': ['Product A', 'Product B', 'Product C', 'Product A', 'Product B'],
#     'Sales': [200, 150, 300, 250, 180],
#     'Month': ['January', 'February', 'March', 'April', 'May']
# }
# df = pd.DataFrame(data)
#
# Using a Pandas DataFrame, demonstrate grouping and aggregation techniques to summarize the data effectively.
# -
# Exercise 5 : Complex Data Visualization
# Instructions
# - Create a multi-plot layout using Matplotlib and plot different types of graphs (e.g., line, scatter, bar) with NumPy-generated data.

# %% [markdown]
# ##Exercise 1 : Advanced Matrix Operations

# %% [markdown]
# ### Create a 5x5 matrix with random numbers and perform the following operations:
# 1. Calculate the eigenvalues and eigenvectors.
# 2. Perform matrix normalization.

# %%
import numpy as np

# Create a 5x5 matrix with random numbers
matrix = np.random.rand(5, 5)
print("Original 5x5 Matrix:")
print(matrix)
# Out:
# Original 5x5 Matrix:
# [[0.21751535 0.19664306 0.9719681  0.00426825 0.89693282]
#  [0.57693878 0.21007641 0.93121696 0.8264869  0.48018484]
#  [0.46978615 0.36073423 0.51281162 0.59993462 0.94304366]
#  [0.7497098  0.4142515  0.64293651 0.90925598 0.45245554]
#  [0.20696125 0.47174893 0.66561146 0.27598646 0.82987591]]

# %%
# Calculate eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(matrix)

print("\nEigenvalues:")
print(eigenvalues)
print("\nEigenvectors:")
print(eigenvectors)
# Out:
# Eigenvalues:
# [ 2.74381005+0.j          0.20932528+0.33410435j  0.20932528-0.33410435j
#  -0.24146267+0.1334137j  -0.24146267-0.1334137j ]
#
# Eigenvectors:
# [[ 0.35575558+0.j          0.69884889+0.j          0.69884889-0.j
#    0.47637451-0.21929963j  0.47637451+0.21929963j]
#  [ 0.49236264+0.j         -0.30749148-0.17890014j -0.30749148+0.17890014j
#    0.62605419+0.j          0.62605419-0.j        ]
#  [ 0.45938733+0.j          0.01685347+0.03376048j  0.01685347-0.03376048j
#   -0.20727421+0.32864514j -0.20727421-0.32864514j]
#  [ 0.51468191+0.j         -0.46035116-0.31582756j -0.46035116+0.31582756j
#   -0.37013572-0.01564185j -0.37013572+0.01564185j]
#  [ 0.39380555+0.j          0.04496022+0.26445887j  0.04496022-0.26445887j
#   -0.12203066-0.17298646j -0.12203066+0.17298646j]]

# %%
# Perform matrix normalization (Min-Max Scaling)
min_val = np.min(matrix)
max_val = np.max(matrix)
normalized_matrix = (matrix - min_val) / (max_val - min_val)

print("\nNormalized Matrix:")
print(normalized_matrix)
# Out:
# Normalized Matrix:
# [[0.22036492 0.19879595 1.         0.         0.92246017]
#  [0.59178529 0.21267768 0.95788866 0.84966289 0.49180186]
#  [0.48105608 0.3683642  0.52551767 0.61554868 0.97011011]
#  [0.77032311 0.42366778 0.6599859  0.93519466 0.46314701]
#  [0.20945854 0.48308438 0.68341771 0.28078769 0.85316502]]

# %% [markdown]
# ## Exercise 2 : Statistical Distribution Analysis

# %% [markdown]
# Exercise 2 : Statistical Distribution Analysis
# Instructions Hint:
#
# - To generate a dataset following a normal distribution, you can use numpy’s np.random.normal() function.
# - For plotting its histogram, matplotlib’s plt.hist() can be used.
# - Generate a dataset following a normal distribution and plot its histogram. Then,
# - calculate and interpret its skewness and kurtosis.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a dataset following a normal distribution
mean = 0
std_dev = 1
num_samples = 1000
normal_data = np.random.normal(mean, std_dev, num_samples)

# Plot its histogram
plt.hist(normal_data, bins=30, density=True, alpha=0.6, color='g')
plt.title('Histogram of a Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from scipy.stats import skew, kurtosis

# Calculate skewness and kurtosis
skewness = skew(normal_data)
kurt = kurtosis(normal_data)

print(f"\nSkewness: {skewness:.4f}")
print(f"Kurtosis: {kurt:.4f}")

# Interpretation
print("\nInterpretation:")
if abs(skewness) < 0.5:
    print("The skewness is close to 0, suggesting the distribution is approximately symmetrical.")
elif skewness > 0:
    print("The skewness is positive, indicating the distribution is skewed to the right.")
else:
    print("The skewness is negative, indicating the distribution is skewed to the left.")

if kurt < 0:
    print("The kurtosis is negative (platykurtic), meaning the distribution has lighter tails and is flatter than a normal distribution.")
elif kurt > 0:
    print("The kurtosis is positive (leptokurtic), meaning the distribution has heavier tails and is more peaked than a normal distribution.")
else:
     print("The kurtosis is close to 0 (mesokurtic), meaning the distribution has a similar peakedness to a normal distribution.")
# Out:
# Skewness: 0.0006
# Kurtosis: -0.0837
#
# Interpretation:
# The skewness is close to 0, suggesting the distribution is approximately symmetrical.
# The kurtosis is negative (platykurtic), meaning the distribution has lighter tails and is flatter than a normal distribution.

# %% [markdown]
# ## Exercise 3 : Time Series Forecasting
#
# Instructions
#
# import numpy as np
#
# - Generating monthly sales data as a NumPy array
# monthly_sales_data = np.random.randint(100, 500, size=12) # Random sales data for 12 months
#
# - Using a simple NumPy array representing time series data (e.g., monthly sales data), demonstrate how to forecast future data points using linear regression.

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Reshape the data for the linear regression model
# The independent variable (X) should be the month number
months = np.arange(1, len(monthly_sales_data) + 1).reshape(-1, 1)
# The dependent variable (y) is the monthly sales data
sales = monthly_sales_data

# Create and train the linear regression model
model = LinearRegression()
model.fit(months, sales)

# Forecast the next few data points (e.g., next 3 months)
future_months = np.arange(len(monthly_sales_data) + 1, len(monthly_sales_data) + 4).reshape(-1, 1)
forecasted_sales = model.predict(future_months)

print("Monthly Sales Data:")
print(monthly_sales_data)
print("\nForecasted Sales for the next 3 months:")
print(forecasted_sales)

# Plot the original data and the forecast
plt.scatter(months, sales, color='blue', label='Original Data')
plt.plot(future_months, forecasted_sales, color='red', label='Forecast')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Data and Forecast using Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Monthly Sales Data:
# [404 369 297 486 407 194 347 295 485 423 391 309]
#
# Forecasted Sales for the next 3 months:
# [363.77272727 363.23776224 362.7027972 ]

# %%
import numpy as np

# Generating monthly sales data as a NumPy array
monthly_sales_data = np.random.randint(100, 500, size=12) # Random sales data for 12 months

# %% [markdown]
# ## Exercise 4 : Pandas Data Aggregation I
#
# nstructions
#
# import pandas as pd
#
# - Creating a sample Pandas DataFrame
# data = { 'Product': ['Product A', 'Product B', 'Product C', 'Product A', 'Product B'], 'Sales': [200, 150, 300, 250, 180], 'Month': ['January', 'February', 'March', 'April', 'May'] } df = pd.DataFrame(data)
#
# - Using a Pandas DataFrame, demonstrate grouping and aggregation techniques to summarize the data effectively.

# %%
import pandas as pd

# Creating a sample Pandas DataFrame
data = {
    'Product': ['Product A', 'Product B', 'Product C', 'Product A', 'Product B'],
    'Sales': [200, 150, 300, 250, 180],
    'Month': ['January', 'February', 'March', 'April', 'May']
}
df = pd.DataFrame(data)

print("Original DataFrame:")
display(df)

# Demonstrate grouping and aggregation
# Group by 'Product' and calculate the sum of 'Sales' for each product
product_sales = df.groupby('Product')['Sales'].sum().reset_index()
print("\nTotal Sales per Product:")
display(product_sales)

# Group by 'Month' and calculate the average 'Sales' for each month
month_avg_sales = df.groupby('Month')['Sales'].mean().reset_index()
print("\nAverage Sales per Month:")
display(month_avg_sales)
# Out:
# Original DataFrame:
#      Product  Sales     Month
# 0  Product A    200   January
# 1  Product B    150  February
# 2  Product C    300     March
# 3  Product A    250     April
# 4  Product B    180       May
# Total Sales per Product:
#      Product  Sales
# 0  Product A    450
# 1  Product B    330
# 2  Product C    300
# Average Sales per Month:
#       Month  Sales
# 0     April  250.0
# 1  February  150.0
# 2   January  200.0
# 3     March  300.0
# 4       May  180.0

# %% [markdown]
# ## Exercise 5 : Complex Data Visualization Instructions
#
# Create a multi-plot layout using Matplotlib and plot different types of graphs (e.g., line, scatter, bar) with NumPy-generated data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
x = np.arange(0, 10, 0.1)
y_line = np.sin(x)
y_scatter = np.random.rand(50)
x_bar = ['A', 'B', 'C', 'D', 'E']
y_bar = np.random.randint(1, 10, size=5)

# Create a multi-plot layout (2x2 grid)
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot a line graph
axes[0, 0].plot(x, y_line, color='blue')
axes[0, 0].set_title('Line Plot')
axes[0, 0].set_xlabel('X-axis')
axes[0, 0].set_ylabel('Y-axis')

# Plot a scatter plot
axes[0, 1].scatter(np.arange(len(y_scatter)), y_scatter, color='red')
axes[0, 1].set_title('Scatter Plot')
axes[0, 1].set_xlabel('Index')
axes[0, 1].set_ylabel('Value')

# Plot a bar chart
axes[1, 0].bar(x_bar, y_bar, color='green')
axes[1, 0].set_title('Bar Chart')
axes[1, 0].set_xlabel('Category')
axes[1, 0].set_ylabel('Value')

# Plot a histogram (using the normal_data from Exercise 2 as an example)
if 'normal_data' in locals():
    axes[1, 1].hist(normal_data, bins=30, density=True, alpha=0.6, color='purple')
    axes[1, 1].set_title('Histogram (Normal Distribution)')
    axes[1, 1].set_xlabel('Value')
    axes[1, 1].set_ylabel('Frequency')
else:
    # Generate some random data for histogram if normal_data is not available
    random_hist_data = np.random.randn(1000)
    axes[1, 1].hist(random_hist_data, bins=30, density=True, alpha=0.6, color='purple')
    axes[1, 1].set_title('Histogram (Random Data)')
    axes[1, 1].set_xlabel('Value')
    axes[1, 1].set_ylabel('Frequency')


# Adjust layout to prevent overlapping titles and labels
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Conclusion
#
# Hereabove, we have explored several key concepts and techniques in data analysis and machine learning using Python libraries like NumPy, Pandas, and Matplotlib.
#
# **Exercise 1: Advanced Matrix Operations**, we practiced:
# - creating matrices,
# - calculating eigenvalues and eigenvectors to understand linear transformations, and
# - performed matrix normalization, a crucial step for many machine learning algorithms.
#
# **Exercise 2: Statistical Distribution Analysis**, we delved into
# - generating and visualizing data following a normal distribution,
# - calculating and interpreting skewness and kurtosis, providing insights into the shape and characteristics of the data distribution.
#
# **Exercise 3: Time Series Forecasting** introduced us to
# - using linear regression to predict future data points based on historical time series data,
# - demonstrating a fundamental forecasting technique.
#
# **Exercise 4: Pandas Data Aggregation** showcased the power of Pandas for
# - summarizing data efficiently by grouping and aggregating information within a DataFrame.
#
# **Exercise 5: Complex Data Visualization** brought together our skills to
# - create multi-plot layouts using Matplotlib, allowing us to visualize different aspects of data using various graph types.
#
# Through these exercises, we have reinforced our understanding of essential mathematical and statistical concepts and gained practical experience in applying them using popular Python libraries for data manipulation, analysis, and visualization.
